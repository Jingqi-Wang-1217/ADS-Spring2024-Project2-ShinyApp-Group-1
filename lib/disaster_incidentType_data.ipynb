# %%
import pandas as pd

df=pd.read_csv("DisasterDeclarationsSummaries.csv")
selected_df = df[['disasterNumber','state','fyDeclared','incidentType','hmProgramDeclared']].drop_duplicates()

labels = {
    'Northeast': ['CT', 'ME', 'MA', 'NH', 'RI', 'VT', 'NJ', 'NY', 'PA', "DE"],
    'Southeast': ['FL', 'GA', 'MD', 'NC', 'SC', 'VA', 'DC', 'WV', "TN", "AL", "KY", "MS", 'VI'],
    'Midwest': ['IL', 'IN', 'IA', 'KS', 'MI', 'MN', 'MO', 'NE', 'ND', 'OH', 'SD', 'WI'],
    'Southwest': ['AR', 'AZ', 'LA', 'NM', 'OK', 'TX'],
    'West': ['AK', 'CA', 'CO', 'HI', 'ID', 'MT', 'NV', 'OR', 'UT', 'WA', 'WY'],
    'Territories': ['AS', 'GU', 'MP', 'PR', "FM"]
}

# Add "Region" column to the df
selected_df['Region'] = selected_df['state'].map(
    {state: region for region, states in labels.items() for state in states})


selected_df.to_csv("disaster_incidentType.csv")

# %%
selected_df
# Out:
#        disasterNumber state  fyDeclared incidentType  hmProgramDeclared  \
# 0                5464    RI        2023         Fire                  1
# 1                5463    KS        2023         Fire                  1
# 2                4731    CO        2023        Flood                  1
# 6                4738    GA        2023    Hurricane                  1
# 8                5444    TX        2022         Fire                  1
# ...               ...   ...         ...          ...                ...
# 64755            1090    MA        1996    Snowstorm                  0
# 64769            1089    KY        1996    Snowstorm                  0
# 64889            1087    NC        1996    Snowstorm                  0
# 64959            1085    PA        1996    Snowstorm                  0
# 65010            1008    CA        1994   Earthquake                  0
#
#           Region
# 0      Northeast
# 1        Midwest
# 2           West
# 6      Southeast
# ...

# %%
# @title fyDeclared

from matplotlib import pyplot as plt
selected_df['fyDeclared'].plot(kind='hist', bins=20, title='fyDeclared')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
selected_df['incidentType'].value_counts()
# Out:
# Fire                 1580
# Severe Storm         1056
# Flood                 884
# Hurricane             442
# Tornado               178
# Snowstorm             171
# Biological            167
# Severe Ice Storm       74
# Typhoon                58
# Drought                46
# Earthquake             36
# Other                  34
# Coastal Storm          31
# Freezing               18
# Mud/Landslide          10
# Winter Storm            9
# Tropical Storm          9
# Toxic Substances        8
# Dam/Levee Break         6
# Volcanic Eruption       6
# Fishing Losses          6
# Human Cause             4
# Tsunami                 3
# Terrorist               2
# Chemical                1
# Name: incidentType, dtype: int64
